# %% [markdown]
# # Create Mock Data
#
# Create mock dataset based on preliminary cleaned data, for dashboard prototyping

# %%
import pandas as pd
import numpy as np

save_csv = True

# %%
# Preliminary cleaned data
rr = pd.read_csv('race_relations_clean_prelim_2020-08-18.csv')
rr.head(2)
# Out:
#    Incident ID                                        Article URL  \
# 0          169  https://www.cbc.ca/news/canada/british-columbi...
# 1          831  https://www.theglobeandmail.com/politics/artic...
#
#                                 Incident Description Publication Date  \
# 0  RCMP are looking for a group of fishermen accu...       2018-08-29
# 1  Conservative leadership candidate, who was dis...       2020-03-24
#
#   Incident Date  Pub Date Minus Incident Date          Province  \
# 0    2018-08-29                           0.0  British Columbia
# 1    2020-03-24                           0.0           Ontario
#
#   City or Region Detailed Location  Incident Category  ...  South Asian  \
# 0           Hope               NaN  Criminal: Unknown  ...          NaN
# 1      Cambridge               NaN       Non-Criminal  ...          NaN
#
#    Southeast Asian                          Identity-Based   Context  \
# 0              NaN                                     NaN       NaN
# 1              NaN  Religious discrimination: Islamophobia  Politics
#
#   Type of Incident                                      Previous Tags  \
# 0              NaN  C; race relations; anti-indigenous; Fraser Riv...
# 1              NaN              NC; political; anti-muslim; Cambridge
#
#   Needs Review                                          D4G Notes CCMF Notes  \
# 0   Check city  Location originally listed as Fraser River, wh...        NaN
# 1   Check city  No mention of the city of Cambridge in the art...        NaN
#
#   Follow-Up Action
# 0              NaN
# 1              NaN
#
# [2 rows x 29 columns]

# %%
# List of all possible categories for each dimension
categories = (pd.read_csv('categories.csv', na_values='', keep_default_na=False)
              .melt(var_name='Dimension', value_name='Value')
              .dropna(subset=['Value'])
             )

# Append some additional multi-select values
extra = [
    ['Gender of Victim(s)', 'Female, Male'],
    ['Ethnic Community', 'Black/African/Caribbean, Indigenous'],
    ['Ethnic Community', 'South Asian, Southeast Asian'],
    ['Ethnic Community', 'Central Asian, Middle Eastern'],
    ['Identity-Based', 'Religious discrimination: Islamophobia, Xenophobia'],
    ['Identity-Based', 'Religious discrimination: Anti-Semitism, Religious discrimination: Islamophobia']
]
extra = pd.DataFrame(extra, columns=['Dimension', 'Value'])
categories = categories.append(extra).set_index('Dimension', drop=True)

print(categories.shape)
categories.sample(10, random_state=0)
# Out:
# (216, 1)
#                                              Value
# Dimension
# Context                                    Transit
# Black/African/Caribbean                    Comoros
# Black/African/Caribbean                       Togo
# Southeast Asian                          Singapore
# Middle Eastern                              Turkey
# Black/African/Caribbean  Saint Pierre and Miquelon
# Black/African/Caribbean                   Zimbabwe
# Middle Eastern                              Cyprus
# Gender of Victim(s)                           Male
# Black/African/Caribbean               South Africa

# %%
def random_choice(choices, n, blank_ratio=2, seed=0):
    """Return a series of random values from a list of choices"""
    
    if blank_ratio > 0:
        choices = choices + int(blank_ratio) * len(choices) * ['']
    
    np.random.seed(seed)
    values = pd.Series(np.random.choice(choices, n)).replace({'' : np.nan})
    
    return values

# %%
# Create dataframe with mock data
cols_drop = ['Publication Date', 'Pub Date Minus Incident Date', 'Previous Tags',
             'Needs Review', 'D4G Notes', 'CCMF Notes', 'Follow-Up Action']
rr_mock = (rr.copy()
           .sort_values('Incident ID')
           .reset_index(drop=True)
           .drop(cols_drop, axis=1)
          )

# For the few entries with multiple URLs listed, extract the first URL
rr_mock['Article URL'] = rr_mock['Article URL'].str.split(expand=True)[0]

# Empty placeholder column
rr_mock['Notes'] = np.nan

# Populate missing values with random selections from applicable categories
n = rr_mock.shape[0]
communities = categories.loc['Ethnic Community', 'Value'].values
for name in categories.index.unique():
    choices = categories.loc[name, 'Value'].to_list()
    
    # Make some of the sub-communities more common than others
    if name == 'Black/African/Caribbean':
        choices += 10 * ['Ethiopia', 'Jamaica', 'Nigeria', 'Somalia']
    elif name == 'Indigenous':
        choices += 5 * ['First Nations']
    elif name == 'East Asian':
        choices += 10 * ['China'] + 5 * ['Japan', 'Taiwan', 'South Korea']
    elif name == 'South Asian':
        choices += 10 * ['India', 'Pakistan']
    elif name == 'Southeast Asian':
        choices += 10 * ['Indonesia', 'Philippines', 'Vietnam']
    elif name == 'Central Asian':
        choices += 10 * ['Afghanistan', 'Iran']
    elif name == 'Middle Eastern':
        choices += 10 * ['Israel', 'Palestine'] + 5 * ['Egypt', 'Iraq', 'Syria']
    elif name == 'Latin American':
        choices += 10 * ['Mexico'] + 5 * ['Brazil', 'Ecuador', 'Venezuela']
        
    if name == 'Incident Category' or name == 'Ethnic Community':
        # No blanks
        blank_ratio = 0
    elif name in communities:
        blank_ratio = 1
    else:
        # Set roughly 2/3 of values to blanks
        blank_ratio = 2
    values = random_choice(choices, n, blank_ratio=blank_ratio)
    rr_mock[name] = rr_mock[name].fillna(values)
    
    # If the column is a sub-community, set values to NaN if the corresponding community is
    # not selected
    if name in communities:
        idx = ~rr_mock['Ethnic Community'].fillna('').str.contains(name)
        rr_mock.loc[idx, name] = np.nan

rr_mock.head(2)
# Out:
#    Incident ID                                        Article URL  \
# 0            1  https://globalnews.ca/news/3949365/b-c-woman-c...
# 1            2  https://www.cbc.ca/news/canada/windsor/graffit...
#
#                                 Incident Description Incident Date  \
# 0  B.C. woman caught on video delivering racist r...    2018-01-05
# 1  Windsor Muslims pen letter asking police why I...    2018-01-03
#
#            Province City or Region Detailed Location Incident Category  \
# 0  British Columbia        Burnaby               NaN      Non-Criminal
# 1           Ontario        Windsor               NaN      Non-Criminal
#
#   Gender of Victim(s)  Name of Victim(s)  ... East Asian Indigenous  \
# 0                 NaN                NaN  ...        NaN        NaN
# 1              Female                NaN  ...        NaN        NaN
#
#   Latin American Middle Eastern South Asian Southeast Asian  \
# 0            NaN            NaN         NaN             NaN
# 1            NaN            NaN         NaN             NaN
#
#                            Identity-Based Context    Type of Incident Notes
# 0                                     NaN     NaN  Hate speech: Other   NaN
# 1  Religious discrimination: Islamophobia     NaN           Vandalism   NaN
#
# [2 rows x 23 columns]

# %%
rr_mock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Incident ID              1000 non-null   int64
#  1   Article URL              1000 non-null   object
#  2   Incident Description     999 non-null    object
#  3   Incident Date            997 non-null    object
#  4   Province                 941 non-null    object
#  5   City or Region           852 non-null    object
#  6   Detailed Location        26 non-null     object
#  7   Incident Category        1000 non-null   object
#  8   Gender of Victim(s)      349 non-null    object
#  9   Name of Victim(s)        0 non-null      float64
#  10  Ethnic Community         1000 non-null   object
#  11  Black/African/Caribbean  165 non-null    object
#  12  Central Asian            50 non-null     object
#  13  East Asian               48 non-null     object
#  14  Indigenous               142 non-null    object
#  15  Latin American           23 non-null     object
#  16  Middle Eastern           54 non-null     object
#  17  South Asian              76 non-null     object
#  18  Southeast Asian          43 non-null     object
#  19  Identity-Based           569 non-null    object
#  20  Context                  582 non-null    object
#  21  Type of Incident         651 non-null    object
#  22  Notes                    0 non-null      float64
# dtypes: float64(2), int64(1), object(20)
# memory usage: 179.8+ KB

# %%
cols = ['Incident Category', 'Gender of Victim(s)'] + rr_mock.columns[10:22].to_list()
for col in cols:
    print('---- ' + col + ' ------')
    print(rr_mock[col].value_counts(dropna=False))
    print('')
# Out:
# ---- Incident Category ------
# Non-Criminal             705
# Criminal: Unknown        161
# Criminal: Charged         69
# Criminal: Not charged     65
# Name: Incident Category, dtype: int64
#
# ---- Gender of Victim(s) ------
# NaN              651
# Female, Male     104
# Female            87
# Other/Unknown     81
# Male              77
# Name: Gender of Victim(s), dtype: int64
#
# ---- Ethnic Community ------
# Black/African/Caribbean                                245
# Indigenous                                             220
# South Asian                                             81
# East Asian                                              78
# Central Asian                                           54
# Middle Eastern                                          51
# Black/African/Caribbean, Indigenous                     49
# Central Asian, Middle Eastern                           46
# N/A                                                     43
# Latin American                                          42
# Southeast Asian                                         41
# South Asian, Southeast Asian                            37
# Black/African/Caribbean, Indigenous, Middle Eastern      7
# Black/African/Caribbean, South Asian                     3
# East Asian, Indigenous                                   1
# Black/African/Caribbean, East Asian                      1
# Indigenous, Middle Eastern                               1
# Name: Ethnic Community, dtype: int64
#
# ---- Black/African/Caribbean ------
# NaN                             835
# Nigeria                          17
# Somalia                          16
# Ethiopia                         15
# Jamaica                          14
#                                ...
# Bahamas                           1
# Congo                             1
# Chad                              1
# United States Virgin Islands      1
# Sao Tome and Principe             1
# Name: Black/African/Caribbean, Length: 66, dtype: int64
#
# ---- Central Asian ------
# NaN             950
# Afghanistan      23
# Iran             18
# Turkmenistan      4
# Kyrgyzstan        4
# Uzbekistan        1
# Name: Central Asian, dtype: int64
#
# ---- East Asian ------
# NaN            952
# China           32
# Taiwan           8
# South Korea      4
# Japan            2
# North Korea      2
# Name: East Asian, dtype: int64
#
# ---- Indigenous ------
# NaN              858
# First Nations    110
# Métis             17
# Inuit             15
# Name: Indigenous, dtype: int64
#
# ---- Latin American ------
# NaN                 977
# Mexico                4
# Brazil                3
# Venezuela             3
# Falkland Islands      2
# Ecuador               2
# Chile                 2
# Uruguay               1
# Peru                  1
# Honduras              1
# Cuba                  1
# French Guiana         1
# Paraguay              1
# Guatemala             1
# Name: Latin American, dtype: int64
#
# ---- Middle Eastern ------
# NaN                     946
# Palestine                12
# Iraq                     10
# Israel                   10
# Egypt                     5
# Syria                     4
# Armenia                   2
# Libya                     2
# Lebanon                   2
# Cyprus                    1
# United Arab Emirates      1
# Saudi Arabia              1
# Qatar                     1
# Kuwait                    1
# Azerbaijan                1
# Israel, Palestine         1
# Name: Middle Eastern, dtype: int64
#
# ---- South Asian ------
# NaN           924
# India          42
# Pakistan       20
# Bangladesh      6
# Bhutan          3
# Maldives        2
# Sri Lanka       2
# Nepal           1
# Name: South Asian, dtype: int64
#
# ---- Southeast Asian ------
# NaN            957
# Philippines     14
# Vietnam         11
# Indonesia        9
# Brunei           3
# Singapore        2
# Thailand         1
# Cambodia         1
# Laos             1
# Malaysia         1
# Name: Southeast Asian, dtype: int64
#
# ---- Identity-Based ------
# NaN                                                                                                                                431
# Religious discrimination: Islamophobia                                                                                             134
# Religious discrimination: Anti-Semitism                                                                                            105
# Xenophobia                                                                                                                          78
# Religious discrimination: Anti-Semitism, Religious discrimination: Islamophobia                                                     38
# Anti-2SLGBTQIA+                                                                                                                     38
# Religious discrimination: Anti-Sikhism                                                                                              36
# Religious discrimination: Islamophobia, Xenophobia                                                                                  34
# Sexism                                                                                                                              33
# Religious discrimination: Anti-Hinduism                                                                                             28
# Religious discrimination: Other                                                                                                     25
# Religious discrimination: Anti-Sikhism, Religious discrimination: Islamophobia                                                       4
# Religious discrimination: Islamophobia, Sexism                                                                                       3
# Anti-2SLGBTQIA+, Religious discrimination: Islamophobia                                                                              2
# Anti-2SLGBTQIA+, Xenophobia                                                                                                          2
# Religious discrimination: Anti-Semitism, Religious discrimination: Anti-Sikhism, Religious discrimination: Islamophobia, Sexism      2
# Religious discrimination: Anti-Semitism, Xenophobia                                                                                  2
# Anti-2SLGBTQIA+, Religious discrimination: Anti-Semitism, Religious discrimination: Islamophobia                                     1
# Religious discrimination: Anti-Semitism, Religious discrimination: Islamophobia, Xenophobia                                          1
# Religious discrimination: Anti-Semitism, Religious discrimination: Anti-Sikhism, Religious discrimination: Islamophobia              1
# Sexism, Xenophobia                                                                                                                   1
# Religious discrimination: Anti-Semitism, Sexism                                                                                      1
# Name: Identity-Based, dtype: int64
#
# ---- Context ------
# NaN                                                            418
# Politics                                                       169
# Educational institute: Other                                    53
# Online: Social media                                            49
# Transit                                                         26
# Online: Other                                                   26
# Educational institute: Post-secondary                           26
# Educational institute: K-12                                     24
# Sports: Hockey                                                  24
# Environmental racism                                            23
# Protective services: Military                                   18
# Workplace                                                       17
# Healthcare/public health                                        16
# Protective services: Police                                     15
# Protective services: Peace officers                             13
# Sports: Football                                                11
# Public space                                                    10
# Sports: Basketball                                               8
# Online: Social media, Politics                                   7
# Protective services: Other                                       7
# Protective services: Security                                    7
# Sports: Other                                                    7
# Online: Other, Politics                                          6
# Educational institute: Other, Politics                           6
# Online: Social media, Protective services: Military              2
# Educational institute: Other, Online: Social media               2
# Politics, Protective services: Military                          2
# Educational institute: Post-secondary, Online: Social media      1
# Educational institute: Other, Online: Other                      1
# Online: Other, Protective services: Military                     1
# Online: Other, Transit                                           1
# Educational institute: Other, Transit                            1
# Politics, Transit                                                1
# Environmental racism, Politics                                   1
# Educational institute: Post-secondary, Sports: Hockey            1
# Name: Context, dtype: int64
#
# ---- Type of Incident ------
# NaN                                              349
# Hate speech: Other                               244
# Vandalism                                        106
# Harassment: Racial profiling                      97
# Harassment: Other                                 47
# Hate speech: Letter/flyer                         41
# Hate speech: Rally/protest                        32
# Hate speech: Imagery                              28
# Other                                             22
# Harassment: Carding                               20
# Harassment: Other, Hate speech: Other              7
# Hate speech: Other, Vandalism                      3
# Harassment: Other, Hate speech: Letter/flyer       2
# Harassment: Other, Hate speech: Rally/protest      1
# Hate speech: Letter/flyer, Vandalism               1
# Name: Type of Incident, dtype: int64

# %% [markdown]
# ## Save to CSV

# %%
def save_data(data, savefile, index=False):
    print(f'Saving to {savefile}')
    data.to_csv(savefile, index=index)

# %%
if save_csv:
    save_data(rr_mock, 'mock_data.csv')
# Out:
# Saving to mock_data.csv
